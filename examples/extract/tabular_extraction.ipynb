# %% [markdown]
# # Extracting from Tabular Document Formats Using LlamaExtract
#
# This notebook demonstrates how to use the `PER_TABLE_ROW` extraction target to extract structured data from documents containing repeating entities like tables, lists, or catalogs.
#
# ## Why Use tabular extraction target?
#
# **The Problem with PER_DOC for Lists**: When extracting lists of entities, LLM-based extraction has a critical failure mode—it often **only extracts the first few tens of entries** from a long list. This happens because LLMs have limited attention spans for repetitive data. Document-level extraction doesn't guarantee exhaustive coverage and long lists lead to incomplete extractions.
#
# **The Solution**: `PER_TABLE_ROW` solves this by processing each entity individually or in smaller batches, ensuring **exhaustive extraction** of all entries regardless of list length.
#
# ### Entity-Level Extraction
#
# When using `extraction_target=ExtractTarget.PER_TABLE_ROW`, you define a schema for a **single entity** (e.g., one hospital, one product, one invoice line item), not the full document. LlamaExtract automatically:
# - Detects the formatting patterns that distinguish individual entities (table rows, list items, section headers, etc.)
# - Applies your schema to each identified entity
# - Returns a `list[YourSchema]` with one object per entity
#
# This approach is ideal when each entity locally contains all the information needed for your schema.
#
# ### Choosing the Right Extraction Target
#
# | Extraction Target | Best For | Returns |
# |-------------------|----------|---------|
# | `PER_DOC` | Single-entity documents, summaries, or short lists | One JSON object for entire document |
# | `PER_PAGE` | Multi-page documents where each page is independent | One JSON object per page |
# | `PER_TABLE_ROW` | **Long lists, tables, catalogs with repeating entities** | List of JSON objects (one per entity) |
#
# 📖 For more details, see the [Extraction Target documentation](https://developers.llamaindex.ai/python/cloud/llamaextract/features/concepts/#extraction-target).

# %%
from dotenv import load_dotenv
from llama_cloud_services import LlamaExtract


# Load environment variables (put LLAMA_CLOUD_API_KEY in your .env file)
load_dotenv(override=True)

# Optionally, add your project id/organization id
llama_extract = LlamaExtract()

# %% [markdown]
# ## Table of Hospitals by County and Insurance Plans
#
# We have a PDF document with a list of hospitals by county and different insurance plans offered by Blue Shield of California.
#
#
# ![First few entries from the PDF](./data/tables/bsc_page1.png)

# %% [markdown]
# We want to extract each hospital from this table along with a list of applicable insurance plans.
#
# ### Example 1: Structured Table
#
# This is an ideal use case for `PER_TABLE_ROW` extraction:
# - **Clear structure**: The document has explicit table formatting with rows and columns
# - **Repeating entities**: Each row represents one hospital with consistent attributes
# - **Local information**: All data for each hospital (county, name, plans) is contained within its row
#
# Notice that our `Hospital` schema describes a **single hospital**, not the full document. LlamaExtract will return a `list[Hospital]` with one entry per table row.

# %%
from pydantic import BaseModel, Field


class Hospital(BaseModel):
    """List of hospitals by county available for different BSC plans"""

    county: str = Field(description="County name")
    hospital_name: str = Field(description="Name of the hospital")
    plan_names: list[str] = Field(
        description="List of plans available at the hospital. One of: Trio HMO, SaveNet, Access+ HMO, BlueHPN PPO, Tandem PPO, PPO"
    )

# %%
from llama_cloud_services.extract import ExtractConfig, ExtractMode, ExtractTarget


result = await llama_extract.aextract(
    data_schema=Hospital,
    files="./data/tables/BSC-Hospital-List-by-County.pdf",
    config=ExtractConfig(
        extraction_mode=ExtractMode.PREMIUM,
        extraction_target=ExtractTarget.PER_TABLE_ROW,
        parse_model="anthropic-sonnet-4.5",
    ),
)

# %% [markdown]
# ### Results

# %%
result.data
# Out:
# [{'county': 'Alameda',
#   'hospital_name': 'Alameda Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Alta Bates Med Ctr Herrick Campus',
#   'plan_names': ['Trio HMO',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Alta Bates Summit Med Ctr Alta Bates Campus',
#   'plan_names': ['Trio HMO',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Alta Bates Summit Med Ctr Summit Campus',
#   'plan_names': ['Trio HMO',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Alta Bates Summit Medical Center',
#   'plan_names': ['Trio HMO',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'BHC Fremont Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Centre For Neuro Skills San Francisco',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Eden Medical Center',
#   'plan_names': ['Trio HMO', 'Access+ HMO', 'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Fairmont Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Highland Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Kindred Hospital San Francisco Bay Area',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Mpi Chemical Dependency Recovery Hospital',
#   'plan_names': ['Trio HMO', 'Access+ HMO', 'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'San Leandro Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'St Rose Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Stanford Health Care Tri-Valley',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': "UCSF Benioff Children's Hospital Oakland",
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Valley Memorial Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Alameda',
#   'hospital_name': 'Washington Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Amador',
#   'hospital_name': 'Sutter Amador Hospital',
#   'plan_names': ['PPO']},
#  {'county': 'Butte',
#   'hospital_name': 'Enloe Medical Center Cohasset',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Butte',
#   'hospital_name': 'Enloe Medical Center Esplanade',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Butte',
#   'hospital_name': 'Enloe Rehabilitation Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Butte',
#   'hospital_name': 'Orchard Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Butte',
#   'hospital_name': 'Oroville Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Calaveras',
#   'hospital_name': 'Mark Twain Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Colusa',
#   'hospital_name': 'Colusa Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Contra Costa',
#   'hospital_name': 'John Muir Behavioral Health Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Contra Costa',
#   'hospital_name': 'John Muir Medical Center Concord Campus',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Contra Costa',
#   'hospital_name': 'John Muir Medical Center Walnut Creek Campus',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Contra Costa',
#   'hospital_name': 'San Ramon Regional Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Contra Costa',
#   'hospital_name': 'Sutter Delta Medical Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Del Norte',
#   'hospital_name': 'Sutter Coast Hospital',
#   'plan_names': ['Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'El Dorado',
#   'hospital_name': 'Barton Memorial Hosp',
#   'plan_names': ['BlueHPN PPO', 'Tandem PPO', 'PPO']},
#  {'county': 'El Dorado',
#   'hospital_name': 'Marshall Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Adventist Med Ctr Reedley',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Clovis Community Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Community Behavioral Health Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Fresno Community Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Fresno Heart and Surgical Hosp A Community Rmcc',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Fresno Surgical Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'San Joaquin Valley Rehabilitation Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'Selma Community Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Fresno',
#   'hospital_name': 'St Agnes Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Glenn',
#   'hospital_name': 'Glenn Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Humboldt',
#   'hospital_name': 'Jerold Phelps Comm Hosp',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Humboldt',
#   'hospital_name': 'Mad River Comm Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Humboldt',
#   'hospital_name': 'Providence Redwood Memorial Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Humboldt',
#   'hospital_name': 'Providence St Joseph Hospital Eureka',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Imperial',
#   'hospital_name': 'El Centro Regional Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Imperial',
#   'hospital_name': 'Pioneers Memorial Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Inyo',
#   'hospital_name': 'Northern Inyo Hosp',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Inyo',
#   'hospital_name': 'Southern Inyo Hospital',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Adventist Health Medical Center Tehachapi',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Bakersfield Behavioral Healthcare Hospital Llc',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Bakersfield Heart Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Bakersfield Memorial Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Bakersfield Rehabilitation Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Centre For Neuro Skills',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Delano Regional Med Ctr',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Encompass Health Rehabilitation Hospital Of Bakersfield',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Good Samaritan Hospital',
#   'plan_names': ['Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Kern Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Kern Valley Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Mercy Hospital Bakersfield',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Mercy Southwest Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'Ridgecrest Regional Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Kern',
#   'hospital_name': 'San Joaquin Comm Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Kings',
#   'hospital_name': 'Adventist Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Lake',
#   'hospital_name': 'Adventist Health Clear Lake',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Lake',
#   'hospital_name': 'Sutter Lakeside Hosp',
#   'plan_names': ['PPO']},
#  {'county': 'Lassen',
#   'hospital_name': 'Banner Lassen Med Ctr',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Adventist Health White Memorial',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Alhambra Hospital Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Antelope Valley Hosp Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Aurora Charter Oak',
#   'plan_names': ['BlueHPN PPO', 'Tandem PPO', 'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Aurora Las Encinas Hospital Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'BHC Alhambra Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Barlow Respiratory Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'California Hosp Med Ctr Los Angeles',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'California Rehabilitation Institute',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Casa Colina Hospital For Rehab Medicine',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Casa Colina Transitional Living Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Catalina Island Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Cedars Sinai Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Childrens Hosp Of Los Angeles',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'City Of Hope National Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Coast Plaza Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'College Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Community Hospital Of Huntington Park',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Del Amo Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Docs Surgical Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Earl and Lorraine Miller Childrens Hsp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'East Los Angeles Doctors Hsp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Emanate Health Foothill Presbyterian Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Emanate Health Inter-Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Emanate Health Queen Of The Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Garfield Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Glendale Adventist Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Glendale Memorial Hosp and Health Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Greater El Monte Community Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Henry Mayo Newhall Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Hollywood Presbyterian Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Huntington Memorial Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Keck Hospital Of Usc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital Baldwin Park',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital La Mirada',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital Los Angeles',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital Paramount',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital San Gabriel Valley',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Kindred Hospital South Bay',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Lakewood Regional Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Long Beach Memorial Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Los Angeles Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Los Angeles Community Hospital At Bellflower',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Los Angeles County Harbor UCLA Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'BlueHPN PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Marina Del Rey Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Martin Luther King Jr Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Memorial Hosp Of Gardena Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Methodist Hosp Of Southern California',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Mission Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Monterey Park Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Motion Picture and Television Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Northridge Hosp Med Ctr Roscoe Campus',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Norwalk Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Olive View UCLA Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'BlueHPN PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Pacifica Hospital Of The Valley',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Palmdale Regional Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Pih Health Good Samaritan Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Pih Health Hospital - Whittier',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Pih Hospital - Downey',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Pomona Valley Hosp Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Cedars Sinai Tarzana Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Holy Cross Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Little Co Of Mary Med Ctr San Pedro',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Little Co Of Mary Med Ctr Torrance',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Saint Johns Health Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Providence Saint Joseph Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Resnick Neuropsychiatric Hospital At UCLA',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Ronald Reagan UCLA Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'San Dimas Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'San Gabriel Valley Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Santa Monica UCLA Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Silver Lake Medical Center Ingleside Campus',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Southern California Hospital At Culver City',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Southern California Hospital At Hollywood',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Southern California Hospital At Van Nuys',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'St Francis Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'St Mary Medical Center Long Beach',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Tarzana Treatment Centers Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Torrance Memorial Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'USC Kenneth Norris Jr Cancer Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'USC Verdugo Hills Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Valley Presbyterian Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'West Covina Medical Center Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'West Hills Hospital Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Los Angeles',
#   'hospital_name': 'Whittier Hospital Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Madera',
#   'hospital_name': 'Valley Childrens Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Marin',
#   'hospital_name': 'Kentfield Rehab Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'BlueHPN PPO', 'PPO']},
#  {'county': 'Marin',
#   'hospital_name': 'Marinhealth and Marinhealth Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Marin',
#   'hospital_name': 'Novato Community Hospital',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Mariposa',
#   'hospital_name': 'John C Fremont Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Mendocino',
#   'hospital_name': 'Adventist Health Howard Memorial',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Mendocino',
#   'hospital_name': 'Adventist Health Mendocino Coast',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Mendocino',
#   'hospital_name': 'Adventist Health Ukiah Valley',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Merced',
#   'hospital_name': 'Memorial Hosp Of Los Banos',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Merced',
#   'hospital_name': 'Mercy Med Ctr Merced Comm Campus',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Modoc',
#   'hospital_name': 'Modoc Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Modoc',
#   'hospital_name': 'Surprise Valley Comm Hosp',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Mono',
#   'hospital_name': 'Mammoth Hospital',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Monterey',
#   'hospital_name': 'Community Hospital Of The Monterey Peninsula',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Monterey',
#   'hospital_name': 'George L Mee Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Monterey',
#   'hospital_name': 'Natividad Medical Center',
#   'plan_names': ['Access+ HMO', 'BlueHPN PPO', 'Tandem PPO', 'PPO']},
#  {'county': 'Monterey',
#   'hospital_name': 'Salinas Valley Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Napa',
#   'hospital_name': 'Adventist Health St Helena',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Napa',
#   'hospital_name': 'Providence Queen Of The Valley Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Nevada',
#   'hospital_name': 'Sierra Nevada Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Nevada',
#   'hospital_name': 'Tahoe Forest Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Aliso Ridge Behavioral Health Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Anaheim Global Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Anaheim Regional Medical Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Chapman Global Medical Center Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Childrens Hospital At Mission',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Childrens Hospital Of Orange County',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'College Hospital Costa Mesa',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Encompass Health Rehabilitation Hospital Of Tustin',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Foothill Regional Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Fountain Valley Regional Hosp and Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Healthbridge Childrens Hospital Orange',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Hoag Hospital Irvine',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Hoag Memorial Hospital Presbyterian',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Hoag Orthopedic Institute',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Kindred Hospital Brea',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Kindred Hospital Santa Ana',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Kindred Hospital Westminster',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Laguna Treatment Hospital Llc',
#   'plan_names': ['Access+ HMO', 'BlueHPN PPO', 'Tandem PPO', 'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Los Alamitos Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Mission Hospital Laguna Beach',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Orange Coast Mem Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Orange County Global Medical Center Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Placentia Linda Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Providence Mission Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Providence St Joseph Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Providence St Jude Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'Saddleback Memorial Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'South Coast Global Medical Center Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Orange',
#   'hospital_name': 'University Of California Irvine Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Placer',
#   'hospital_name': 'Sutter Auburn Faith Hosp',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Placer',
#   'hospital_name': 'Sutter Roseville Medical Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Plumas',
#   'hospital_name': 'Eastern Plumas Hospital',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Plumas',
#   'hospital_name': 'Plumas District Hospital',
#   'plan_names': ['Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Plumas',
#   'hospital_name': 'Seneca District Hosp',
#   'plan_names': ['Tandem PPO', 'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Corona Regional Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Desert Regional Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Eisenhower Medical Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Encompass Health Rehabilitation Hospital Of Murrieta',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Hemet Global Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'John F Kennedy Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Kindred Hospital Riverside',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Loma Linda University Med Ctr Murrieta',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Menifee Global Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Pacific Grove Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Palo Verde Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Parkview Community Hospital Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Riverside Community Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'San Gorgonio Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Southwest Healthcare Inland Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Southwest Healthcare Rancho Springs Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Temecula Valley Hospital Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'The Betty Ford Center At Eisenhower',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Riverside',
#   'hospital_name': 'Vibra Rehabilitation Hospital Of Rancho Mirage',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Heritage Oaks Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Mercy General Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Mercy Hospital Of Folsom',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Mercy San Juan Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Methodist Hosp Of Sacramento',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Sacramento Behavioral Healthcare Hospital Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Sacramento Rehabilitation Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Shriners Hospitals For Children Northern CA',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Sierra Vista Hosp Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Sutter Center For Psychiatry',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Sutter Medical Center Sacramento',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'UC Davis Medical Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sacramento',
#   'hospital_name': 'Vibra Hospital Of Sacramento',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Benito',
#   'hospital_name': 'Hazel Hawkins Memorial Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Arrowhead Regional Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Ballard Rehabilitation Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Barstow Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Bear Valley Comm Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Canyon Ridge Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Colorado River Medical Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Community Hosp Of San Bernardino',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Desert Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Hi Desert Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Kindred Hospital Ontario',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Kindred Hospital Rancho',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Loma Linda University Behavioral Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Loma Linda University Childrens Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Loma Linda University Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Mountains Community Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Providence St Mary Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Redlands Community Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'San Antonio Comm Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'St Bernardine Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Bernardino',
#   'hospital_name': 'Victor Valley Global Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Alvarado Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Alvarado Hospital Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Alvarado Parkway Inst Bhs',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Aurora San Diego Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Grossmont Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Kindred Hospital San Diego',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Palomar Health',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Palomar Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Palomar Rehabilitation Institute',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Paradise Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Rady Childrens Hospital San Diego',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Scripps Green Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Scripps Memorial Hospital Encinitas',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
# ...
#   'hospital_name': 'Sharp Chula Vista Med Ctr',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Sharp Coronado Hosp and Healthcare Ctr',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Sharp Mary Birch Hosp For Women and Newborns',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Sharp Mcdonald Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Sharp Memorial Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Sharp Mesa Vista Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'Tri City Medical Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'UCSD La Jolla John Sally Thornton',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Diego',
#   'hospital_name': 'UCSD Medical Ctr',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'California Pacific Medical Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'California Pacific Medical Center - D P Aph',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'California Pacific Medical Center - Mission Bernal Campus and Orthopedic Institute',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'California Pacific Medical Center Van Ness Campus',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'Chinese Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'Jewish Home',
#   'plan_names': ['BlueHPN PPO', 'Tandem PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'Kentfield Hospital San Francisco',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'Medical Ctr At UCSF',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'St Francis Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'St Marys Medical Center San Francisco',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'UCSF Medical Center At Mission Bay',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Francisco',
#   'hospital_name': 'UCSF Medical Center At Mount Zion',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'Adventist Health Lodi Memorial',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'Dameron Hospital Assoc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'Doctors Hospital Of Manteca',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'San Joaquin General Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'St Josephs Behavioral Health Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'St Josephs Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Joaquin',
#   'hospital_name': 'Sutter Tracy Community Hosp',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Luis Obispo',
#   'hospital_name': 'French Hospital Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'San Luis Obispo',
#   'hospital_name': 'Marian Regional Medical Ctr Arroyo Grande',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'San Luis Obispo',
#   'hospital_name': 'Sierra Vista Regional Med Ctr',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'San Luis Obispo',
#   'hospital_name': 'Twin Cities Community Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'San Mateo',
#   'hospital_name': 'Ahmc Seton Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Mateo',
#   'hospital_name': 'Ahmc Seton Medical Center Coastside',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'San Mateo',
#   'hospital_name': 'Mills Health Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Mateo',
#   'hospital_name': 'Mills-Peninsula Medical Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'San Mateo',
#   'hospital_name': 'Sequoia Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Barbara',
#   'hospital_name': 'Goleta Valley Cottage Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Santa Barbara',
#   'hospital_name': 'Lompoc Valley Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Santa Barbara',
#   'hospital_name': 'Marian Regional Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Santa Barbara',
#   'hospital_name': 'Santa Barbara Cottage Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Santa Barbara',
#   'hospital_name': 'Santa Ynez Valley Cottage Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'El Camino Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'El Camino Hospital Los Gatos',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Good Samaritan Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Lucile Salter Packard Childrens Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Mission Oaks Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Oconnor Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Regional Medical Ctr Of San Jose',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'San Jose Behavioral Health',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Santa Clara Valley Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'St Louise Regional Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Clara',
#   'hospital_name': 'Stanford Health Care',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Cruz',
#   'hospital_name': 'Dominican Santa Cruz Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Santa Cruz',
#   'hospital_name': 'Sutter Maternity and Surgery Center Of Santa Cruz',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Santa Cruz',
#   'hospital_name': 'Watsonville Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Shasta',
#   'hospital_name': 'Mayers Memorial Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Shasta',
#   'hospital_name': 'Mercy Medical Center Redding',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Shasta',
#   'hospital_name': 'Shasta Regional Medical Ctr',
#   'plan_names': ['Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Shasta',
#   'hospital_name': 'Vibra Hospital Of Northern California',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Siskiyou',
#   'hospital_name': 'Fairchild Medical Center',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Siskiyou',
#   'hospital_name': 'Mercy Medical Ctr Mt Shasta',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Solano',
#   'hospital_name': 'Adventist Health Vallejo',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Solano',
#   'hospital_name': 'North Bay Vacavalley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Solano',
#   'hospital_name': 'Northbay Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Solano',
#   'hospital_name': 'Sutter Solano Med Ctr',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Aurora Behavioral Healthcare Santa Rosa Llc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Healdsburg Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Petaluma Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Providence Santa Rosa Memorial Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Sonoma Specialty Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Sonoma Valley Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Sonoma',
#   'hospital_name': 'Sutter Santa Rosa Regional Hospital',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Central Valley Specialty Hosp Inc',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Doctors Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Emanuel Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Encompass Health Rehabilitation Hospital Of Modesto',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Memorial Hospital Med Ctr',
#   'plan_names': ['Trio HMO', 'Access+ HMO', 'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Oak Valley Dist Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Stanislaus',
#   'hospital_name': 'Stanislaus Surgical Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Sutter',
#   'hospital_name': 'Sutter Surgical Hospital North Valley',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Tehama',
#   'hospital_name': 'St Elizabeth Comm Hsp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Trinity',
#   'hospital_name': 'Trinity Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Tulare',
#   'hospital_name': 'Adventist Health Tulare',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Tulare',
#   'hospital_name': 'Kaweah Delta District Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Tulare',
#   'hospital_name': 'Kaweah Delta Mental Health Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Tulare',
#   'hospital_name': 'Sierra View District Hosp',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'Tandem PPO', 'PPO']},
#  {'county': 'Tuolumne',
#   'hospital_name': 'Sonora Regional Medical Center',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Community Memorial Hosp Of San Buenaventura',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Los Robles Regional Med Ctr',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Ojai Valley Community Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Santa Paula Hospital',
#   'plan_names': ['Trio HMO', 'SaveNet', 'Access+ HMO', 'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Simi Valley Hosp and Health Care Svs',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'St Johns Regional Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Ventura County Medical Center',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Ventura',
#   'hospital_name': 'Vista Del Mar Hospital',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Yolo',
#   'hospital_name': 'Sutter Davis Hospital',
#   'plan_names': ['Access+ HMO', 'PPO']},
#  {'county': 'Yolo',
#   'hospital_name': 'Woodland Memorial Hosp',
#   'plan_names': ['Trio HMO',
#    'SaveNet',
#    'Access+ HMO',
#    'BlueHPN PPO',
#    'Tandem PPO',
#    'PPO']},
#  {'county': 'Yuba',
#   'hospital_name': 'Adventist Health and Rideout',
#   'plan_names': ['Tandem PPO', 'PPO']}]

# %% [markdown]
# ![](./data/tables/bsc_results.png)

# %%
len(result.data)
# Out:
# 380

# %% [markdown]
# ## Extracting from a Toy Catalog
#
# ### Example 2: Semi-Structured List
#
# The `PER_TABLE_ROW` extraction target also works well for documents that aren't explicit tables but have similar properties:
# - **Ordered listing**: The toys are listed sequentially with visual separation (section headers, spacing)
# - **Repeating pattern**: Each toy entry has a consistent structure (code, name, specs, description)
# - **Local information**: All attributes for each toy are grouped together in its entry
#
# Even though this isn't a traditional table format, each toy entity locally contains all the information needed for our schema. LlamaExtract detects the formatting patterns that distinguish each toy and extracts them as separate entities.
#
# ![](./data/tables/toy_catalog_page.png)

# %%
from pydantic import BaseModel, Field
from typing import Optional


class ToyCatalog(BaseModel):
    """Product information from a toy catalog."""

    section_name: str = Field(
        description="The name of the toy section (e.g., Table Toys, Active Toys)."
    )
    product_code: str = Field(
        description="The unique product code for the toy (e.g., GA457)."
    )
    toy_name: str = Field(description="The name of the toy.")
    age_range: Optional[str] = Field(
        default=None,
        description="The recommended age range for the toy (e.g., 6 +, 4 +).",
    )
    player_range: Optional[str] = Field(
        default=None,
        description="The number of players the toy is designed for (e.g., 2, 2-4, 1-6).",
    )
    material: Optional[str] = Field(
        default=None,
        description="The primary material(s) the toy is made of (e.g., wood, cardboard).",
    )
    description: Optional[str] = Field(
        default=None,
        description="A brief description of the toy and its components and dimensions.",
    )

# %% [markdown]
# ### Results
#
# Again, our schema represents a **single toy product**, not the entire catalog. The system will return a `list[ToyCatalog]` with one entry per toy.

# %%
result = await llama_extract.aextract(
    data_schema=ToyCatalog,
    files="./data/tables/toy_catalog_page.png",
    config=ExtractConfig(
        extraction_mode=ExtractMode.PREMIUM,
        extraction_target=ExtractTarget.PER_TABLE_ROW,
        parse_model="anthropic-sonnet-4.5",
    ),
)

# %%
result.data
# Out:
# [{'section_name': 'Table Toys',
#   'product_code': '/null',
#   'toy_name': 'Which Cow am i?',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': None,
#   'description': None},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA457',
#   'toy_name': 'Dots and Boxes',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'base 17x17 cm\n50 border pieces 4x1,2x0,3 cm\n34 trees 2,6x1,4 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA456',
#   'toy_name': '5 in a Row',
#   'age_range': '8+',
#   'player_range': '2',
#   'material': 'wood, pine, cardboard',
#   'description': 'base 24x22,5x2,5 cm\n30 cards 5,5x5 cm\n6 chips'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA467',
#   'toy_name': 'Which Cow am i?',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, beech',
#   'description': '2 cow bases 56x4x4,5 cm\n36 cards 4x5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA460',
#   'toy_name': 'Balance Bunnies',
#   'age_range': '4+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '1 base 35x12x25 cm\n7 bunnies 7 foxes\n1 dice 3 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA462',
#   'toy_name': 'Color Combination Race',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': 'base 6,5x6,5x15 cm, rings 5,5x5,5x0,5 mm; cardholder 6x6x2 cm, cards 5,5x5,5 cm; color cards ⌀ 15,5 cm - ⌀ 7 cm'}]

# %% [markdown]
# ![](./data/tables/toy_catalog_results.png)

# %% [markdown]
# ## Summary
#
# The `PER_TABLE_ROW` extraction target is powerful for extracting repeating structured entities from documents. Key takeaways:
#
# 1. **Schema design**: Define your schema for a single entity, not the full document. The system returns `list[YourSchema]`.
#
# 2. **Works with various formats**: Not just traditional tables—any document with distinguishable repeating entities (bullets, numbering, headers, visual separation, etc.)
#
# 3. **Local information**: Each entity should contain all the necessary data for your schema within its local context.
#
# 4. **Automatic pattern detection**: LlamaExtract identifies the formatting patterns that distinguish entities and applies your schema to each one.
